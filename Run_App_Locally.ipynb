# %%
# !pip install streamlit gdown pyngrok

# %%
# !git clone https://github.com/sukhijashivam/multiple-disease-prediction.git
# %cd multiple-disease-prediction
# Out:
# Cloning into 'multiple-disease-prediction'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 39 (delta 15), reused 14 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (39/39), 36.56 KiB | 567.00 KiB/s, done.
# Resolving deltas: 100% (15/15), done.
# /content/multiple-disease-prediction/multiple-disease-prediction

# %%
# !pip install -r requirements.txt
# Out:
# ...
# ERROR: Ignored the following versions that require a different python version: 0.55.2 Requires-Python <3.5
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.10.0 (from versions: 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0, 2.17.1, 2.18.0rc0, 2.18.0rc1, 2.18.0rc2, 2.18.0, 2.18.1, 2.19.0rc0, 2.19.0, 2.19.1, 2.20.0rc0, 2.20.0)
# ERROR: No matching distribution found for tensorflow==2.10.0

# %%
# !pip install streamlit pyngrok

# %%
# !pip install pyngrok

from pyngrok import ngrok
ngrok.set_auth_token("35gPiaQIU93x8ysHoTBJrP4MWKg_JJ768CBzProf7Jb6vq7C")

# %%
from pyngrok import ngrok
import threading, time, os

# 🔹 Start Streamlit app
def run_app():
    os.system("streamlit run app.py --server.port 8501")

threading.Thread(target=run_app).start()

# 🔹 Wait a few seconds for Streamlit to start
time.sleep(5)

# 🔹 Create public URL with ngrok
public_url = ngrok.connect(8501)
print("🌍 Public URL:", public_url)
# Out:
# 🌍 Public URL: NgrokTunnel: "https://subpatronal-joane-unsotted.ngrok-free.dev" -> "http://localhost:8501"
